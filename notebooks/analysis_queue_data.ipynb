# %%
import pandas as pd
import json

path = "../data/bronze/parks_queue_times/2026/08/06/parks_queue_2026-08-06_15-05-30.json"

# %%
with open(path) as f:
    data = json.load(f)

print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# {
#   "lands": [
#     {
#       "id": 761,
#       "name": "Coasters",
#       "rides": [
#         {
#           "id": 96,
#           "name": "Colossus",
#           "is_open": true,
#           "wait_time": 10,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 13079,
#           "name": "Hyperia",
#           "is_open": true,
#           "wait_time": 65,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 88,
#           "name": "Nemesis Inferno",
#           "is_open": true,
#           "wait_time": 5,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 104,
#           "name": "SAW - The Ride",
#           "is_open": true,
#           "wait_time": 15,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 91,
#           "name": "Stealth",
#           "is_open": true,
#           "wait_time": 5,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 103,
#           "name": "The Swarm",
#           "is_open": true,
#           "wait_time": 5,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 5558,
#           "name": "The Walking Dead©: The Ride",
#           "is_open": true,
#           "wait_time": 5,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         }
#       ]
#     },
#     {
#       "id": 763,
#       "name": "Family rides",
#       "rides": [
#         {
#           "id": 14526,
#           "name": "Amity Beach",
#           "is_open": false,
#           "wait_time": 0,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 3884,
#           "name": "Big Easy Bumpers",
#           "is_open": true,
#           "wait_time": 5,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 108,
#           "name": "Depth Charge",
#           "is_open": true,
#           "wait_time": 15,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 95,
#           "name": "Dobble Tea Party",
#           "is_open": true,
#           "wait_time": 5,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 93,
#           "name": "Flying Fish",
#           "is_open": true,
#           "wait_time": 5,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 10711,
#           "name": "High Striker",
#           "is_open": true,
#           "wait_time": 5,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 109,
#           "name": "Mr Monkey's Banana Ride",
#           "is_open": true,
#           "wait_time": 5,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         }
#       ]
#     },
#     {
#       "id": 762,
#       "name": "Thrill rides",
#       "rides": [
#         {
#           "id": 89,
#           "name": "Detonator",
#           "is_open": true,
#           "wait_time": 5,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 4546,
#           "name": "Ghost Train",
#           "is_open": true,
#           "wait_time": 10,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 102,
#           "name": "Quantum",
#           "is_open": true,
#           "wait_time": 5,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 98,
#           "name": "Rush",
#           "is_open": true,
#           "wait_time": 20,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 99,
#           "name": "Samurai",
#           "is_open": true,
#           "wait_time": 10,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 94,
#           "name": "Storm Surge",
#           "is_open": true,
#           "wait_time": 45,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 92,
#           "name": "Tidal Wave",
#           "is_open": true,
#           "wait_time": 5,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 100,
#           "name": "Vortex",
#           "is_open": false,
#           "wait_time": 0,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         },
#         {
#           "id": 101,
#           "name": "Zodiac",
#           "is_open": false,
#           "wait_time": 0,
#           "last_updated": "2026-08-06T17:59:47.000Z"
#         }
#       ]
#     }
#   ],
#   "rides": []
# }

# %%
data["lands"]
# Out:
# [{'id': 761,
#   'name': 'Coasters',
#   'rides': [{'id': 96,
#     'name': 'Colossus',
#     'is_open': True,
#     'wait_time': 10,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 13079,
#     'name': 'Hyperia',
#     'is_open': True,
#     'wait_time': 65,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 88,
#     'name': 'Nemesis Inferno',
#     'is_open': True,
#     'wait_time': 5,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 104,
#     'name': 'SAW - The Ride',
#     'is_open': True,
#     'wait_time': 15,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 91,
#     'name': 'Stealth',
#     'is_open': True,
#     'wait_time': 5,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 103,
#     'name': 'The Swarm',
#     'is_open': True,
#     'wait_time': 5,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 5558,
#     'name': 'The Walking Dead©: The Ride',
#     'is_open': True,
#     'wait_time': 5,
#     'last_updated': '2026-08-06T17:59:47.000Z'}]},
#  {'id': 763,
#   'name': 'Family rides',
#   'rides': [{'id': 14526,
#     'name': 'Amity Beach',
#     'is_open': False,
#     'wait_time': 0,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 3884,
#     'name': 'Big Easy Bumpers',
#     'is_open': True,
#     'wait_time': 5,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 108,
#     'name': 'Depth Charge',
#     'is_open': True,
#     'wait_time': 15,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 95,
#     'name': 'Dobble Tea Party',
#     'is_open': True,
#     'wait_time': 5,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 93,
#     'name': 'Flying Fish',
#     'is_open': True,
#     'wait_time': 5,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 10711,
#     'name': 'High Striker',
#     'is_open': True,
#     'wait_time': 5,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 109,
#     'name': "Mr Monkey's Banana Ride",
#     'is_open': True,
#     'wait_time': 5,
#     'last_updated': '2026-08-06T17:59:47.000Z'}]},
#  {'id': 762,
#   'name': 'Thrill rides',
#   'rides': [{'id': 89,
#     'name': 'Detonator',
#     'is_open': True,
#     'wait_time': 5,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 4546,
#     'name': 'Ghost Train',
#     'is_open': True,
#     'wait_time': 10,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 102,
#     'name': 'Quantum',
#     'is_open': True,
#     'wait_time': 5,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 98,
#     'name': 'Rush',
#     'is_open': True,
#     'wait_time': 20,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 99,
#     'name': 'Samurai',
#     'is_open': True,
#     'wait_time': 10,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 94,
#     'name': 'Storm Surge',
#     'is_open': True,
#     'wait_time': 45,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 92,
#     'name': 'Tidal Wave',
#     'is_open': True,
#     'wait_time': 5,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 100,
#     'name': 'Vortex',
#     'is_open': False,
#     'wait_time': 0,
#     'last_updated': '2026-08-06T17:59:47.000Z'},
#    {'id': 101,
#     'name': 'Zodiac',
#     'is_open': False,
#     'wait_time': 0,
#     'last_updated': '2026-08-06T17:59:47.000Z'}]}]
